# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('tough_dataset.csv')
df
# Out:
#             id  Target A  Target B  LOAN_AMT  \
# 0     68407277  42405.00         0      3600
# 1     68355089  60740.00         1     24700
# 2     68341763  51907.68         0     20000
# 3     66310712  51907.68         0     35000
# 4     68476807     35.00         1     10400
# ...        ...       ...       ...       ...
# 2941  68394526  67757.00         0     14000
# 2942  68404684  67757.00         1     18675
# 2943  68414567  54100.00         0     24000
# 2944  68373599  54100.00         0      2500
# 2945  68172458  36390.00         0     10000
#
#                                          Business Title  \
# 0                                       Account Manager
# 1              EXECUTIVE DIRECTOR, BUSINESS DEVELOPMENT
# 2     Maintenance Worker - Technical Services-Heatin...
# 3     Maintenance Worker - Technical Services-Heatin...
# 4                                     Temporary Painter
# ...                                                 ...
# ...

# %%
df.head()
# Out:
#          id  Target A  Target B  LOAN_AMT  \
# 0  68407277  42405.00         0      3600
# 1  68355089  60740.00         1     24700
# 2  68341763  51907.68         0     20000
# 3  66310712  51907.68         0     35000
# 4  68476807     35.00         1     10400
#
#                                       Business Title  \
# 0                                    Account Manager
# 1           EXECUTIVE DIRECTOR, BUSINESS DEVELOPMENT
# 2  Maintenance Worker - Technical Services-Heatin...
# 3  Maintenance Worker - Technical Services-Heatin...
# 4                                  Temporary Painter
#
#               Civil Service Title              Division/Work Unit  \
# 0  CONTRACT REVIEWER (OFFICE OF L            Strategy & Analytics
# 1  ADMINISTRATIVE BUSINESS PROMOT            Tech Talent Pipeline
# 2              MAINTENANCE WORKER  Management Services Department
# 3              MAINTENANCE WORKER  Management Services Department
# ...

# %%
text_features = []
for i in df:
    print(i,df[i][0],df[i][1])
    if type(df[i][0]) ==str:
        text_features.append(i)
# Out:
# id 68407277 68355089
# Target A 42405.0 60740.0
# Target B 0 1
# LOAN_AMT 3600 24700
# Business Title Account Manager EXECUTIVE DIRECTOR, BUSINESS DEVELOPMENT
# Civil Service Title CONTRACT REVIEWER (OFFICE OF L ADMINISTRATIVE BUSINESS PROMOT
# Division/Work Unit Strategy & Analytics Tech Talent Pipeline
# ...

# %%
print(text_features,len(text_features))
# Out:
# ['Business Title', 'Civil Service Title', 'Division/Work Unit', 'Job Description', 'Minimum Qual Requirements', 'Preferred Skills', 'Additional Information', 'Residency Requirement', 'Posting Date', 'Posting Updated', 'Process Date', 'FormalEducation', 'UndergradMajor', 'CompanySize', 'DevType', 'YearsCoding', 'YearsCodingProf', 'HopeFiveYears', 'JobSearchStatus', 'LastNewJob', 'UpdateCV', 'CommunicationTools', 'TimeFullyProductive', 'EducationTypes', 'SelfTaughtTypes', 'HackathonReasons', 'AgreeDisagree1', 'AgreeDisagree2', 'AgreeDisagree3', 'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith', 'DatabaseDesireNextYear', 'PlatformWorkedWith', 'PlatformDesireNextYear', 'FrameworkWorkedWith', 'FrameworkDesireNextYear', 'IDE', 'OperatingSystem', 'Methodology', 'VersionControl', 'CheckInCode', 'AIDangerous', 'AIInteresting', 'AIResponsible', 'AIFuture', 'Age', 'term', 'emp_length', 'loan_status', 'pymnt_plan', 'url', 'purpose', 'title', 'zip_code', 'addr_state', 'earliest
# ...

# %%
df2 = df

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
import warnings
warnings.filterwarnings("ignore")
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix
np.random.seed(123)

label_encoder = LabelEncoder()

for i in text_features:
    df2[i] = label_encoder.fit_transform(df2[i])
#     data.iloc[:,0] = label_encoder.fit_transform(data.iloc[:,0]).astype('float64')

# %%
df2
# Out:
#             id  Target A  Target B  LOAN_AMT  Business Title  \
# 0     68407277  42405.00         0      3600              37
# 1     68355089  60740.00         1     24700             610
# 2     68341763  51907.68         0     20000             828
# 3     66310712  51907.68         0     35000             828
# 4     68476807     35.00         1     10400            1189
# ...        ...       ...       ...       ...             ...
# 2941  68394526  67757.00         0     14000            1095
# 2942  68404684  67757.00         1     18675            1095
# 2943  68414567  54100.00         0     24000             393
# 2944  68373599  54100.00         0      2500             393
# 2945  68172458  36390.00         0     10000              45
#
#       Civil Service Title  Division/Work Unit  Job Description  \
# 0                     143                 603              180
# 1                      14                 616             1289
# ...

# %%
corr = df.corr()

# %%
sns.heatmap(corr)
# Out:
# <AxesSubplot:>

# %%
corr
# Out:
#                           id  Target A  Target B  LOAN_AMT  Business Title  \
# id                  1.000000 -0.010424  0.017360  0.004329        0.034837
# Target A           -0.010424  1.000000  0.007766 -0.005426       -0.063531
# Target B            0.017360  0.007766  1.000000 -0.053278        0.034943
# LOAN_AMT            0.004329 -0.005426 -0.053278  1.000000       -0.034276
# Business Title      0.034837 -0.063531  0.034943 -0.034276        1.000000
# ...                      ...       ...       ...       ...             ...
# dti                 0.037443  0.002491  0.001063  0.038297        0.003072
# earliest_cr_line    0.004450 -0.003691  0.054061  0.119739       -0.002966
# last_pymnt_d        0.021132 -0.001529  0.021266  0.009710       -0.018453
# last_pymnt_amnt    -0.021086  0.009170 -0.049296  0.435464       -0.010145
# last_credit_pull_d  0.023598 -0.002745  0.021427  0.009841        0.000227
#
# ...

# %%
corr.to_csv('corr.csv')

# %%
x = df2.drop(['Target A', 'Target B'],axis=1)
x
# Out:
#             id  LOAN_AMT  Business Title  Civil Service Title  \
# 0     68407277      3600              37                  143
# 1     68355089     24700             610                   14
# 2     68341763     20000             828                  219
# 3     66310712     35000             828                  219
# 4     68476807     10400            1189                  234
# ...        ...       ...             ...                  ...
# 2941  68394526     14000            1095                  140
# 2942  68404684     18675            1095                  140
# 2943  68414567     24000             393                  122
# 2944  68373599      2500             393                  122
# 2945  68172458     10000              45                  116
#
#       Division/Work Unit  Job Description  Minimum Qual Requirements  \
# 0                    603              180                         14
# 1                    616             1289                         91
# ...

# %%
ya = df2[['Target A']]
ya
# Out:
#       Target A
# 0     42405.00
# 1     60740.00
# 2     51907.68
# 3     51907.68
# 4        35.00
# ...        ...
# 2941  67757.00
# 2942  67757.00
# 2943  54100.00
# 2944  54100.00
# 2945  36390.00
#
# [2946 rows x 1 columns]

# %%
yb = df2[['Target B']]
yb
# Out:
#       Target B
# 0            0
# 1            1
# 2            0
# 3            0
# 4            1
# ...        ...
# 2941         0
# 2942         1
# 2943         0
# 2944         0
# 2945         0
#
# [2946 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
print(X_test.shape,X_train.shape,y_test.shape,y_test.shape)
# Out:
# (590, 67) (2356, 67) (590, 2) (590, 2)

# %%
ya_train = y_train[['Target A']]
yb_train = y_train[['Target B']]
ya_train
yb_train
# Out:
#       Target B
# 2665         0
# 2798         0
# 456          0
# 462          0
# 2178         0
# ...        ...
# 1638         0
# 1095         0
# 1130         0
# 1294         0
# 860          0
#
# [2356 rows x 1 columns]

# %%
ya_test = y_test[['Target A']]
yb_test = y_test[['Target B']]
ya_test
yb_test
# Out:
#       Target B
# 565          0
# 1220         0
# 1677         0
# 1577         0
# 2833         0
# ...        ...
# 1255         0
# 2560         0
# 2935         0
# 1412         0
# 685          0
#
# [590 rows x 1 columns]

# %%
from keras import Sequential
from keras.layers import Dense

classifier = Sequential()
classifier.add(Dense(100, activation='relu', kernel_initializer='random_normal', input_dim=18))
classifier.add(Dense(50, activation='relu', kernel_initializer='random_normal'))
classifier.add(Dense(25, activation='relu', kernel_initializer='random_normal'))
classifier.add(Dense(5, activation='relu', kernel_initializer='random_normal'))
classifier.add(Dense(1, activation='sigmoid', kernel_initializer='random_normal'))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-92-918dde398e9e> in <module>
# ----> 1 from keras import Sequential
#       2 from keras.layers import Dense
#       3
#       4 classifier = Sequential()
#       5 classifier.add(Dense(100, activation='relu', kernel_initializer='random_normal', input_dim=18))
#
# ModuleNotFoundError: No module named 'keras'
